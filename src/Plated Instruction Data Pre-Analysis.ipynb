# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# pre-analysis:
# tags: single tag stats; overlapped tag stats; recipe with multiple tags;
# instruction data: 长度；词频统计； （分类做）

# %%
original = pd.read_csv('/Users/hetianbai/Desktop/Plated/nyu_recipe_data.csv')

# %%
original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2562 entries, 0 to 2561
# Data columns (total 18 columns):
# external_id            2562 non-null object
# title                  2562 non-null object
# subtitle               1766 non-null object
# carbs                  1148 non-null float64
# fat                    1148 non-null float64
# protein                1148 non-null float64
# chef_id                2562 non-null int64
# calories               2442 non-null object
# cooking_tips           2427 non-null object
# story                  2425 non-null object
# ingredients_display    2562 non-null object
# step_one               2558 non-null object
# step_two               2557 non-null object
# step_three             2556 non-null object
# step_four              2553 non-null object
# step_five              2551 non-null object
# step_six               2524 non-null object
# recipe_tags            2508 non-null object
# dtypes: float64(3), int64(1), object(14)
# memory usage: 360.4+ KB

# %%
df = pd.read_csv('/Users/hetianbai/Desktop/Plated/cleaned_recipe_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 31 columns):
# Unnamed: 0                    2508 non-null int64
# external_id                   2508 non-null object
# title                         2508 non-null object
# subtitle                      1743 non-null object
# carbs                         1148 non-null float64
# fat                           1148 non-null float64
# protein                       1148 non-null float64
# chef_id                       2508 non-null int64
# calories                      2438 non-null object
# cooking_tips                  2418 non-null object
# story                         2423 non-null object
# ingredients_display           2508 non-null object
# step_one                      2504 non-null object
# step_two                      2504 non-null object
# step_three                    2504 non-null object
# step_four                     2502 non-null object
# step_five                     2500 non-null object
# step_six                      2476 non-null object
# recipe_tags                   2508 non-null object
# tag_cuisine_indian            2508 non-null int64
# tag_cuisine_nordic            2508 non-null int64
# tag_cuisine_european          2508 non-null int64
# tag_cuisine_asian             2508 non-null int64
# tag_cuisine_mexican           2508 non-null int64
# tag_cuisine_latin-american    2508 non-null int64
# tag_cuisine_french            2508 non-null int64
# tag_cuisine_italian           2508 non-null int64
# tag_cuisine_african           2508 non-null int64
# tag_cuisine_mediterranean     2508 non-null int64
# tag_cuisine_american          2508 non-null int64
# tag_cuisine_middle-eastern    2508 non-null int64
# dtypes: float64(3), int64(14), object(14)
# memory usage: 607.5+ KB

# %%
# total number of recipes:
print('total number of recipes:',df.shape[0])
# total number of tags: 
print('total number of tags:',tags.shape[1]+2)
print('total number of tags in model:',tags.shape[1])
# Out:
# total number of recipes: 2508
# total number of tags: 13
# total number of tags in model: 11

# %% [markdown]
# Removed very rare tags: tag_cuisine_nordic, tag_cuisine_african

# %%
data = df[['carbs', 'fat','title',
       'protein','calories', 'step_one', 'step_two', 'step_three',
       'step_four', 'step_five', 'step_six',
       'tag_cuisine_indian',
       'tag_cuisine_asian', 'tag_cuisine_mexican',
       'tag_cuisine_latin-american', 'tag_cuisine_french',
       'tag_cuisine_italian',
       'tag_cuisine_mediterranean', 'tag_cuisine_american',
       'tag_cuisine_middle-eastern']]
data.columns = [['carbs', 'fat','title',
       'protein','calories', 'step_one', 'step_two', 'step_three',
       'step_four', 'step_five', 'step_six', 'Indian', 'Asian', 'Mexican','Latin-american',\
                 'French','Italian','Mediterranean','American','Middle-eastern']]
tags = data[['Indian', 'Asian', 'Mexican','Latin-american',\
                 'French','Italian','Mediterranean','American','Middle-eastern']]

# %%
tags_sum = pd.DataFrame(np.sum(tags,axis=0), columns=['counts'])

# %%
tags_sum
# Out:
#                 counts
# Indian              59
# Asian              457
# Mexican             34
# Latin-american     238
# French             194
# Italian            585
# Mediterranean      192
# American           686
# Middle-eastern     116

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(14,8))

# Generate some sequential data
x = np.array(tags_sum.index)
y = np.array(tags_sum.counts)
sns.barplot(x, y,color="steelblue", ax=ax)
ax.set_ylabel("Number of recipe")
ax.set_xlabel("Cuisines")
plt.title('Number of Recipes by Cuisines')

# %% [markdown]
# Recipe with mutliple tags:

# %%
tags['sum'] = np.array(np.sum(tags,axis=1))
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tags = tags[tags['sum']>0]
tags_multi = tags[tags['sum']>1]
del tags_multi['sum']

# %%
annot_count = np.zeros([9,9])
for i, tag1 in enumerate(list(tags_sum.index)):
    for j, tag2 in enumerate(list(tags_sum.index)):
        if i==j:
            annot_count[i][j] = int((np.array(np.sum(tags_multi[[tag1]],axis=1))>0).sum())
        else:   
            annot_count[i][j] = int((np.array(np.sum(tags_multi[[tag1,tag2]],axis=1))>1).sum())

# %%
for i, tag in enumerate(list(tags_sum.index)):
    annot_count[i][i] = int(tags[tags[tag]==1].shape[0])

# %% [markdown]
# heat map of recipe with maltiple tags

# %%
plt.figure(figsize = (12,12))
sns.set(font_scale=1.5)
sns.heatmap(tags_multi.corr(method='pearson', min_periods=1), annot = annot_count, vmax=.4, square=True, annot_kws={"size": 16})

# %%
def count_length(col):
    length = np.zeros(len(data[col]))
    for i,v in enumerate(list(data[col].values)):
        if isinstance(v, float):
            length[i] = 0
        else:
            length[i] = len(v.split())
    return length

# %%
for col in ['step_one', 'step_two', 'step_three', 'step_four', 'step_five', 'step_six']:
    n = col+'_length'
    data[n]=count_length(col)

data['mean_length'] = data.iloc[:, -7:-1].mean(axis=1)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.set_style("white")
plt.figure(figsize = (12,8))
for tag in list(tags_sum.index):
    sns.distplot(data[data[tag]>0]['mean_length'], bins=50, label= tag, hist=False);
plt.legend()
plt.xlabel('Instruction Length')
plt.title('Instruction Length distribution by Cuisine')
# Out:
# /anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Single Tag statistics:

# %%
for tag in list(tags_sum.index):
    print('>>>>>', tag)
    print('* Numer of recipes', tags_sum.loc[tag].values)
    print('* Average Instruction length:', np.mean(data[data[tag] > 0]['mean_length']))
#    print('* Calories:', np.mean(int(data[data[tag] > 0]['calories'])))
# Out:
# >>>>> Indian
# * Numer of recipes [59]
# * Average Instruction length: 43.87570621468927
# >>>>> Asian
# * Numer of recipes [457]
# * Average Instruction length: 42.50948212983226
# >>>>> Mexican
# * Numer of recipes [34]
# * Average Instruction length: 35.66666666666667
# >>>>> Latin-american
# * Numer of recipes [238]
# * Average Instruction length: 45.24859943977592
# >>>>> French
# * Numer of recipes [194]
# * Average Instruction length: 43.85051546391751
# >>>>> Italian
# * Numer of recipes [585]
# * Average Instruction length: 42.05555555555554
# >>>>> Mediterranean
# * Numer of recipes [192]
# * Average Instruction length: 41.82291666666668
# >>>>> American
# * Numer of recipes [686]
# * Average Instruction length: 42.66399416909625
# >>>>> Middle-eastern
# * Numer of recipes [116]
# * Average Instruction length: 43.73132183908045

# %% [markdown]
# ### High frequent word statistics:

# %%
import string
import pickle as pkl
import random
from collections import Counter, defaultdict
from nltk.tokenize import word_tokenize
from collections import Counter

# lowercase and remove punctuation
def tokenizer(sent):
    #print(sent)
    if pd.isnull(sent):
        words = []
    else:
        table = str.maketrans(string.punctuation, ' '*len(string.punctuation))
        sent = sent.translate(table)
        tokens = word_tokenize(sent)
        # convert to lower case
        tokens = [w.lower() for w in tokens]
        # remove punctuation from each word
        #table = str.maketrans('', '', string.punctuation)
        #stripped = [w.translate(table) for w in tokens]
        # remove remaining tokens that are not alphabetic
        words = [word for word in tokens if word.isalpha()]
        #re.findall(r'\d+', 'sdfa')
    return words

def tokenize_dataset(step_n):
    """returns tokenization for each step, training set tokenizatoin"""
    token_dataset = []
    for sample in step_n:
        tokens = tokenizer(sample)
        token_dataset.extend(tokens)
    return token_dataset

# %%
for tag in list(tags_sum.index):
    words_bucket = []
    for step in ['step_one', 'step_two', 'step_three', 'step_four', 'step_five', 'step_six']:
        words_bucket.extend(tokenize_dataset(data[data[tag] > 0][step]))
    ordered_dict = Counter(words_bucket)
    print(tag)
    print(ordered_dict.most_common(260)[20:])
# Out:
# Indian
# [('stir', 120), ('as', 119), ('about', 118), ('then', 115), ('pot', 115), ('from', 115), ('into', 114), ('rinse', 100), ('for', 99), ('rice', 96), ('remove', 94), ('remaining', 93), ('garlic', 87), ('bowl', 84), ('spinach', 83), ('ginger', 82), ('onion', 81), ('cut', 81), ('recipe', 81), ('tip', 81), ('when', 80), ('water', 78), ('tablespoon', 76), ('combine', 76), ('chicken', 74), ('see', 74), ('desired', 73), ('curry', 70), ('while', 70), ('halve', 69), ('serve', 68), ('stirring', 67), ('large', 66), ('on', 66), ('baking', 66), ('cilantro', 64), ('season', 64), ('discard', 63), ('oven', 60), ('set', 60), ('sheet', 60), ('aside', 59), ('mince', 59), ('olive', 59), ('small', 58), ('leaves', 58), ('inch', 57), ('bring', 57), ('transfer', 57), ('cauliflower', 56), ('cover', 56), ('reduce', 55), ('shimmering', 55), ('boil', 54), ('peel', 53), ('simmer', 52), ('serving', 52), ('paper', 51), ('stems', 51), ('lime', 51), ('through', 51), ('sauce', 50), ('towel', 49), ('half', 48), ('divide', 48), ('between', 47), ('chop', 46), ('more', 45), ('dry', 44), ('fragrant', 44), ('all', 43), ('pat', 43), ('coat', 42), ('paste', 41), ('coconut', 41), ('chickpeas', 41), ('using', 40), ('are', 40), ('thinly', 39), ('skin', 39), ('the', 39), ('naan', 39), ('trim', 38), ('warm', 38), ('preheat', 37), ('slice', 37), ('pieces', 37), ('once', 37), ('place', 37), ('butter', 37), ('needed', 36), ('roast', 36), ('foil', 36), ('vegetables', 36), ('roughly', 35), ('yogurt', 35), ('taste', 35), ('discarding', 34), ('tender', 34), ('mix', 34), ('canola', 34), ('plates', 34), ('whisk', 33), ('toss', 33), ('cup', 33), ('together', 33), ('minute', 32), ('ready', 31), ('juice', 31), ('layer', 30), ('single', 29), ('lemon', 29), ('side', 29), ('spice', 29), ('cooks', 29), ('dig', 29), ('shallot', 28), ('arrange', 28), ('golden', 28), ('low', 28), ('fully', 28), ('sauté', 28), ('carrots', 27), ('fork', 27), ('top', 27), ('garnish', 27), ('bowls', 27), ('or', 26), ('still', 26), ('step', 26), ('spoon', 26), ('roasted', 26), ('cooked', 25), ('up', 25), ('ghee', 25), ('soft', 25), ('produce', 24), ('cups', 24), ('if', 23), ('tablespoons', 23), ('keep', 23), ('milk', 23), ('covered', 22), ('line', 22), ('wedges', 21), ('browned', 21), ('increase', 21), ('stand', 20), ('separate', 20), ('warmed', 20), ('return', 20), ('evenly', 20), ('lengthwise', 19), ('florets', 19), ('brown', 19), ('slightly', 19), ('masala', 19), ('dice', 18), ('potatoes', 18), ('green', 18), ('softened', 18), ('sided', 18), ('wilted', 18), ('let', 17), ('absorbed', 17), ('fluff', 17), ('plate', 17), ('wrap', 17), ('drain', 17), ('bake', 17), ('thickened', 17), ('just', 17), ('beef', 16), ('lamb', 16), ('seeds', 16), ('tomato', 16), ('broccoli', 16), ('vegetable', 16), ('excess', 16), ('has', 16), ('crosswise', 15), ('tomatoes', 15), ('finely', 15), ('cucumber', 15), ('off', 15), ('your', 15), ('drizzle', 15), ('foamy', 15), ('at', 14), ('per', 14), ('whole', 14), ('pinch', 14), ('slotted', 14), ('prepared', 14), ('any', 14), ('alongside', 14), ('mint', 13), ('stack', 13), ('allow', 13), ('soften', 13), ('tear', 13), ('toast', 13), ('beginning', 13), ('reduced', 13), ('potato', 12), ('slices', 12), ('marinade', 12), ('again', 12), ('liquid', 12), ('chile', 12), ('translucent', 12), ('use', 12), ('have', 12), ('lightly', 12), ('occasionally', 12), ('meatballs', 12), ('sautéed', 12), ('rings', 11), ('no', 11), ('longer', 11), ('pink', 11), ('knife', 11), ('chutney', 11), ('uncover', 11), ('pick', 11), ('drip', 11), ('meanwhile', 11), ('crisp', 11), ('you', 11), ('tikka', 11), ('cod', 11), ('save', 11), ('clean', 11), ('reserved', 11), ('enjoy', 11), ('parsley', 10), ('marinate', 10), ('turmeric', 10), ('teaspoons', 10), ('knob', 10)]
# European
# [('bowl', 69), ('tip', 68), ('see', 67), ('recipe', 67), ('then', 63), ('desired', 63), ('from', 61), ('high', 59), ('on', 57), ('garlic', 57), ('remaining', 56), ('sheet', 56), ('into', 53), ('oven', 52), ('black', 52), ('baking', 52), ('transfer', 51), ('tablespoon', 51), ('cut', 50), ('halve', 50), ('season', 50), ('for', 48), ('set', 47), ('all', 47), ('chicken', 47), ('paper', 46), ('potatoes', 46), ('cook', 45), ('while', 44), ('parsley', 43), ('lemon', 43), ('the', 42), ('slice', 42), ('remove', 42), ('half', 41), ('when', 41), ('chop', 40), ('combine', 40), ('toss', 40), ('aside', 39), ('inch', 39), ('rinse', 38), ('dry', 38), ('towel', 38), ('large', 38), ('shimmering', 38), ('side', 37), ('stir', 36), ('pat', 35), ('once', 34), ('thinly', 33), ('steaks', 33), ('serving', 32), ('roast', 32), ('about', 31), ('layer', 31), ('plates', 31), ('stems', 30), ('water', 30), ('stirring', 30), ('browned', 30), ('small', 29), ('leaves', 29), ('sauce', 29), ('preheat', 28), ('onion', 28), ('discarding', 28), ('arrange', 28), ('using', 28), ('or', 28), ('roasted', 27), ('peel', 26), ('pot', 26), ('step', 25), ('top', 25), ('slices', 24), ('tomato', 24), ('between', 24), ('peppers', 24), ('vegetables', 24), ('produce', 23), ('tender', 23), ('golden', 23), ('divide', 23), ('dig', 23), ('discard', 22), ('roughly', 22), ('more', 22), ('lengthwise', 22), ('separate', 22), ('bake', 22), ('down', 21), ('serve', 21), ('are', 20), ('sear', 20), ('through', 20), ('single', 20), ('place', 19), ('mince', 19), ('together', 19), ('butter', 18), ('chives', 18), ('finely', 18), ('your', 18), ('up', 17), ('shallot', 17), ('plate', 17), ('cover', 17), ('softened', 17), ('sprinkle', 17), ('paste', 17), ('juice', 17), ('skin', 16), ('vinegar', 16), ('bell', 16), ('whisk', 16), ('still', 16), ('beef', 16), ('tablespoons', 16), ('spinach', 15), ('cooked', 15), ('rice', 15), ('at', 14), ('boil', 14), ('clean', 14), ('egg', 14), ('fully', 14), ('bread', 14), ('garnish', 14), ('bring', 13), ('shallots', 13), ('coat', 13), ('mushrooms', 13), ('cheese', 13), ('red', 13), ('brown', 13), ('return', 13), ('spoon', 13), ('paprika', 13), ('use', 13), ('mix', 12), ('sherry', 12), ('sauté', 12), ('line', 11), ('off', 11), ('keeping', 11), ('fork', 11), ('kale', 11), ('lightly', 11), ('cooks', 11), ('mixture', 11), ('crust', 11), ('flour', 11), ('per', 11), ('drizzle', 11), ('carrots', 10), ('green', 10), ('beans', 10), ('salad', 10), ('greens', 10), ('stem', 10), ('piquillo', 10), ('wipe', 10), ('knife', 10), ('almonds', 10), ('fragrant', 10), ('hands', 10), ('manchego', 10), ('trim', 9), ('ends', 9), ('reserve', 9), ('edges', 9), ('make', 9), ('cutting', 9), ('board', 9), ('each', 9), ('reduce', 9), ('simmer', 9), ('rosemary', 9), ('gently', 9), ('potato', 9), ('cup', 9), ('rest', 9), ('slightly', 9), ('soften', 8), ('crosswise', 8), ('them', 8), ('drain', 8), ('sides', 8), ('dough', 8), ('pieces', 8), ('teaspoons', 8), ('whites', 8), ('tomatoes', 8), ('mayonnaise', 8), ('wedges', 8), ('arugula', 8), ('pastry', 8), ('spice', 8), ('warm', 8), ('herbs', 8), ('save', 8), ('minute', 8), ('taste', 8), ('smooth', 8), ('glass', 8), ('honey', 8), ('cream', 8), ('piri', 8), ('rare', 8), ('cod', 8), ('dressing', 8), ('khachapuri', 8), ('has', 8), ('temperature', 7), ('let', 7), ('flip', 7), ('no', 7), ('longer', 7), ('form', 7), ('dill', 7), ('wine', 7), ('mustard', 7), ('seeds', 7), ('whole', 7), ('aioli', 7), ('parchment', 7), ('ready', 7), ('even', 7), ('shrimp', 7), ('spacing', 7), ('apart', 7), ('pork', 7), ('carefully', 7), ('leaving', 7), ('brighten', 7), ('beginning', 7), ('meanwhile', 7), ('occasionally', 7), ('roll', 7)]
# Asian
# [('sauce', 921), ('as', 911), ('bowl', 879), ('pot', 853), ('then', 844), ('into', 830), ('cook', 826), ('about', 826), ('water', 809), ('rinse', 799), ('for', 795), ('teaspoon', 737), ('discard', 711), ('stir', 709), ('remove', 701), ('on', 669), ('set', 663), ('remaining', 637), ('aside', 631), ('large', 631), ('when', 612), ('cut', 574), ('slice', 573), ('combine', 565), ('garlic', 557), ('sesame', 552), ('while', 543), ('ginger', 538), ('chicken', 537), ('tip', 534), ('thinly', 530), ('shimmering', 528), ('tablespoon', 515), ('desired', 513), ('season', 513), ('recipe', 512), ('see', 505), ('trim', 503), ('paper', 503), ('inch', 498), ('soy', 491), ('greens', 469), ('towel', 466), ('dry', 447), ('halve', 443), ('scallion', 429), ('small', 417), ('the', 413), ('transfer', 413), ('pat', 398), ('boil', 393), ('stirring', 388), ('between', 383), ('bring', 381), ('half', 381), ('divide', 379), ('leaves', 377), ('serve', 376), ('canola', 376), ('together', 369), ('mince', 363), ('cover', 356), ('place', 355), ('toss', 341), ('lime', 338), ('vegetables', 334), ('through', 331), ('all', 329), ('whisk', 320), ('oven', 318), ('discarding', 314), ('coat', 303), ('more', 300), ('sheet', 296), ('using', 296), ('side', 293), ('top', 291), ('lengthwise', 288), ('skin', 286), ('reduce', 285), ('baking', 285), ('tender', 283), ('stems', 280), ('scallions', 279), ('taste', 275), ('or', 272), ('dark', 266), ('light', 265), ('separate', 262), ('browned', 260), ('serving', 253), ('pieces', 250), ('garnish', 249), ('noodles', 248), ('simmer', 245), ('needed', 245), ('plates', 240), ('once', 238), ('whites', 237), ('clean', 236), ('still', 235), ('crosswise', 234), ('cooked', 231), ('seeds', 229), ('chop', 228), ('beef', 226), ('plate', 224), ('vinegar', 223), ('warm', 217), ('roots', 215), ('layer', 215), ('spoon', 212), ('are', 212), ('fully', 210), ('cooks', 208), ('roast', 207), ('wine', 206), ('drain', 206), ('low', 205), ('choy', 205), ('bok', 204), ('green', 203), ('step', 200), ('up', 196), ('roughly', 195), ('fork', 192), ('cilantro', 192), ('dig', 192), ('preheat', 190), ('produce', 189), ('covered', 188), ('sugar', 185), ('your', 182), ('brown', 181), ('pork', 181), ('evenly', 179), ('wipe', 179), ('cups', 177), ('onion', 174), ('single', 173), ('golden', 171), ('juice', 169), ('steak', 166), ('keeping', 165), ('broccoli', 164), ('minute', 159), ('sauté', 159), ('per', 158), ('steaks', 158), ('stand', 157), ('foil', 157), ('bowls', 157), ('peel', 156), ('return', 154), ('at', 153), ('use', 153), ('it', 151), ('slices', 151), ('sriracha', 149), ('salmon', 147), ('keep', 143), ('mushrooms', 140), ('sear', 139), ('olive', 138), ('bottom', 138), ('shallot', 138), ('ready', 137), ('off', 137), ('arrange', 134), ('if', 134), ('fluff', 133), ('spinach', 131), ('marinade', 130), ('boiling', 128), ('thai', 127), ('cucumber', 126), ('meanwhile', 126), ('carrots', 125), ('tablespoons', 125), ('let', 123), ('fry', 123), ('coconut', 122), ('bell', 122), ('much', 122), ('curry', 122), ('fragrant', 121), ('down', 118), ('miso', 117), ('peanuts', 117), ('paste', 116), ('cup', 115), ('mix', 111), ('drizzle', 109), ('lettuce', 108), ('basil', 108), ('beans', 106), ('black', 105), ('fish', 105), ('seconds', 105), ('chinese', 104), ('cooking', 103), ('shrimp', 103), ('tofu', 103), ('kosher', 103), ('you', 102), ('pour', 101), ('chile', 100), ('sweet', 99), ('potatoes', 99), ('nonstick', 99), ('butter', 98), ('roasted', 98), ('cold', 96), ('hoisin', 95), ('long', 94), ('under', 94), ('peas', 94), ('red', 94), ('reserving', 92), ('occasionally', 92), ('wedges', 91), ('mint', 90), ('enjoy', 90), ('squash', 89), ('less', 89), ('liquid', 88), ('sides', 88), ('allow', 88), ('again', 86), ('pinch', 86), ('slightly', 86), ('absorbed', 85), ('vegetable', 85), ('just', 85), ('mixture', 83), ('pink', 82), ('softened', 82), ('salad', 82), ('egg', 81), ('warmed', 80)]
# Mexican
# [('onion', 62), ('from', 60), ('cook', 58), ('cut', 53), ('as', 53), ('high', 53), ('on', 53), ('lime', 52), ('tablespoon', 52), ('olive', 51), ('the', 51), ('halve', 50), ('oven', 49), ('remove', 49), ('bowl', 48), ('when', 47), ('combine', 45), ('stir', 43), ('needed', 43), ('inch', 42), ('chicken', 41), ('large', 39), ('set', 39), ('half', 39), ('remaining', 39), ('taste', 39), ('tortillas', 39), ('aside', 38), ('shimmering', 37), ('serve', 36), ('discard', 34), ('place', 34), ('for', 32), ('garlic', 32), ('cilantro', 31), ('discarding', 31), ('paper', 30), ('season', 29), ('mince', 29), ('then', 29), ('juice', 29), ('towel', 28), ('divide', 28), ('preheat', 27), ('side', 27), ('corn', 27), ('tomatoes', 26), ('small', 26), ('evenly', 26), ('peel', 25), ('pieces', 25), ('between', 25), ('dry', 24), ('leaves', 23), ('stems', 23), ('through', 23), ('water', 23), ('while', 23), ('each', 23), ('avocado', 23), ('degrees', 22), ('f', 22), ('dice', 22), ('warm', 22), ('using', 21), ('thinly', 21), ('slice', 21), ('teaspoon', 21), ('chop', 21), ('plates', 21), ('pat', 20), ('steak', 20), ('foil', 20), ('sauce', 20), ('golden', 20), ('top', 20), ('poblano', 19), ('lengthwise', 19), ('per', 19), ('pot', 19), ('beans', 19), ('spinach', 19), ('rice', 19), ('baking', 19), ('seeds', 18), ('plate', 18), ('black', 18), ('sheet', 18), ('browned', 17), ('drain', 17), ('layer', 17), ('spoon', 17), ('vegetables', 17), ('meanwhile', 17), ('jalape', 16), ('n', 16), ('brown', 16), ('cover', 16), ('toss', 16), ('more', 16), ('cheese', 16), ('tilapia', 15), ('transfer', 14), ('tender', 14), ('all', 13), ('at', 13), ('o', 13), ('wedges', 13), ('chile', 13), ('lined', 13), ('together', 13), ('simmer', 13), ('cooked', 12), ('diced', 12), ('vegetable', 12), ('carefully', 12), ('coat', 12), ('spice', 12), ('are', 12), ('cup', 12), ('shredded', 12), ('skin', 12), ('wash', 11), ('roughly', 11), ('bring', 11), ('slices', 11), ('wrap', 11), ('squash', 11), ('fork', 11), ('single', 11), ('mixture', 11), ('both', 11), ('sides', 11), ('soft', 11), ('sprinkle', 11), ('canola', 11), ('mix', 11), ('tablespoons', 11), ('bake', 11), ('garnish', 11), ('recipe', 10), ('tip', 10), ('desired', 10), ('swiss', 10), ('chard', 10), ('low', 10), ('allow', 10), ('minute', 10), ('hot', 10), ('filling', 10), ('out', 10), ('if', 9), ('just', 9), ('boil', 9), ('bell', 9), ('up', 9), ('whisk', 9), ('red', 9), ('cooks', 9), ('or', 9), ('clean', 9), ('mushrooms', 9), ('stack', 9), ('scoop', 9), ('flesh', 9), ('bottom', 9), ('salsa', 9), ('see', 8), ('separate', 8), ('save', 8), ('remainder', 8), ('zest', 8), ('quarter', 8), ('warmed', 8), ('cups', 8), ('reduce', 8), ('still', 8), ('cumin', 8), ('stirring', 8), ('translucent', 8), ('ready', 8), ('wilted', 8), ('smoking', 8), ('drizzle', 8), ('pork', 8), ('yogurt', 8), ('pit', 8), ('queso', 8), ('fresco', 8), ('pick', 7), ('dough', 7), ('use', 7), ('another', 7), ('sugar', 7), ('tomato', 7), ('pinch', 7), ('ground', 7), ('least', 7), ('outside', 7), ('down', 7), ('sauté', 7), ('keep', 7), ('softened', 7), ('vinegar', 7), ('few', 7), ('immediately', 7), ('alongside', 7), ('limes', 6), ('your', 6), ('teaspoons', 6), ('plantains', 6), ('finely', 6), ('fish', 6), ('slightly', 6), ('minced', 6), ('wipe', 6), ('marinate', 6), ('occasionally', 6), ('working', 6), ('return', 6), ('grill', 6), ('charred', 6), ('beginning', 6), ('sliced', 6), ('onions', 6), ('batches', 6), ('honey', 6), ('sour', 6), ('cream', 6), ('jack', 6), ('quesadillas', 6), ('stem', 5), ('sear', 5), ('rest', 5), ('off', 5), ('produce', 5), ('green', 5), ('liquid', 5), ('chorizo', 5), ('shallot', 5)]
# Latin-american
# [('bowl', 511), ('lime', 508), ('remaining', 489), ('into', 486), ('olive', 473), ('desired', 466), ('for', 464), ('from', 458), ('then', 451), ('about', 444), ('high', 400), ('cut', 398), ('rinse', 396), ('tip', 380), ('tablespoon', 375), ('chicken', 374), ('set', 372), ('on', 363), ('aside', 357), ('half', 355), ('recipe', 348), ('cilantro', 342), ('stir', 331), ('onion', 329), ('season', 327), ('discarding', 326), ('garlic', 325), ('using', 322), ('cook', 321), ('when', 320), ('see', 310), ('while', 305), ('oven', 303), ('tortillas', 303), ('combine', 299), ('remove', 295), ('large', 285), ('shimmering', 277), ('transfer', 276), ('discard', 275), ('inch', 273), ('juice', 269), ('paper', 249), ('place', 248), ('baking', 237), ('the', 236), ('sheet', 234), ('slice', 232), ('black', 232), ('side', 231), ('serve', 227), ('chop', 227), ('towel', 224), ('small', 219), ('pot', 218), ('leaves', 216), ('or', 207), ('thinly', 207), ('layer', 206), ('toss', 204), ('dry', 201), ('avocado', 201), ('mix', 198), ('stems', 192), ('all', 190), ('pat', 185), ('through', 184), ('lengthwise', 176), ('preheat', 175), ('spoon', 173), ('together', 172), ('serving', 171), ('between', 171), ('water', 170), ('roughly', 169), ('mince', 168), ('divide', 167), ('spice', 163), ('top', 163), ('vegetables', 162), ('more', 159), ('tablespoons', 155), ('plates', 154), ('beans', 153), ('roast', 152), ('single', 150), ('peel', 147), ('tomatoes', 146), ('corn', 146), ('sauce', 145), ('stirring', 143), ('plate', 139), ('carefully', 137), ('seeds', 136), ('rice', 135), ('up', 134), ('coat', 134), ('foil', 133), ('whisk', 133), ('if', 131), ('jalapeño', 131), ('warm', 130), ('needed', 128), ('your', 128), ('skin', 127), ('per', 125), ('browned', 125), ('produce', 124), ('taste', 124), ('dig', 121), ('use', 120), ('cover', 119), ('arrange', 117), ('golden', 113), ('cup', 112), ('are', 112), ('tender', 111), ('ready', 110), ('step', 110), ('dice', 110), ('drain', 110), ('knife', 109), ('beef', 107), ('bake', 107), ('bell', 105), ('pieces', 104), ('out', 104), ('wedges', 103), ('canola', 103), ('clean', 102), ('tomato', 102), ('steaks', 102), ('garnish', 101), ('salsa', 100), ('roasted', 99), ('at', 97), ('squash', 96), ('spinach', 95), ('crema', 95), ('boil', 93), ('scoop', 93), ('drizzle', 93), ('warmed', 93), ('filling', 92), ('sear', 89), ('flesh', 89), ('steak', 89), ('bring', 88), ('pit', 88), ('reduce', 87), ('cooked', 86), ('once', 86), ('wipe', 84), ('poblano', 84), ('simmer', 81), ('remainder', 80), ('cooks', 80), ('greens', 79), ('stack', 79), ('fork', 78), ('return', 77), ('stem', 76), ('separate', 76), ('meanwhile', 76), ('sauté', 76), ('cheese', 76), ('evenly', 75), ('each', 74), ('off', 74), ('much', 74), ('chipotle', 74), ('sprinkle', 73), ('vinegar', 72), ('wrap', 72), ('quinoa', 71), ('grill', 71), ('you', 70), ('fully', 69), ('still', 68), ('softened', 68), ('teaspoons', 67), ('slaw', 67), ('enjoy', 67), ('brown', 66), ('smooth', 65), ('cream', 65), ('another', 64), ('red', 64), ('finely', 64), ('working', 64), ('sour', 64), ('potatoes', 63), ('parsley', 63), ('it', 63), ('slices', 63), ('crisp', 63), ('monterey', 63), ('jack', 63), ('save', 62), ('minute', 62), ('scallion', 60), ('keep', 60), ('board', 59), ('rest', 59), ('down', 59), ('mayonnaise', 59), ('marinade', 58), ('tortilla', 58), ('fragrant', 58), ('tilapia', 58), ('shrimp', 57), ('less', 57), ('pink', 56), ('crosswise', 56), ('salad', 56), ('light', 55), ('reserving', 54), ('strips', 53), ('lightly', 53), ('lined', 53), ('cutting', 52), ('paste', 51), ('kosher', 51), ('pick', 50), ('line', 49), ('sliced', 49), ('chopped', 49), ('trim', 48), ('charred', 48), ('no', 47), ('liquid', 47), ('shallot', 47), ('marinate', 47), ('blender', 47), ('batches', 47), ('sweet', 46), ('quarter', 46), ('soft', 46), ('dough', 46), ('longer', 45)]
# French
# [('olive', 437), ('from', 434), ('on', 399), ('then', 398), ('cook', 380), ('desired', 362), ('season', 324), ('into', 314), ('bowl', 312), ('chicken', 312), ('tip', 304), ('rinse', 297), ('recipe', 292), ('cut', 291), ('remove', 290), ('potatoes', 284), ('oven', 283), ('see', 283), ('tablespoon', 279), ('side', 278), ('when', 275), ('halve', 274), ('high', 269), ('butter', 260), ('remaining', 258), ('set', 248), ('while', 246), ('transfer', 243), ('sheet', 243), ('lemon', 240), ('baking', 239), ('slice', 236), ('aside', 236), ('large', 235), ('paper', 227), ('inch', 220), ('all', 218), ('half', 215), ('dry', 211), ('towel', 211), ('toss', 208), ('place', 206), ('thinly', 205), ('vegetables', 201), ('more', 200), ('garlic', 199), ('shallot', 196), ('for', 196), ('shimmering', 190), ('pat', 188), ('stir', 187), ('discard', 173), ('the', 171), ('stirring', 169), ('plates', 165), ('combine', 164), ('through', 163), ('serve', 163), ('water', 162), ('are', 158), ('discarding', 157), ('golden', 154), ('top', 154), ('tender', 153), ('roast', 150), ('layer', 149), ('stems', 148), ('together', 147), ('chop', 145), ('leaves', 145), ('between', 145), ('preheat', 139), ('onion', 138), ('peel', 137), ('divide', 137), ('green', 136), ('sauce', 135), ('pot', 133), ('arrange', 131), ('thyme', 126), ('tablespoons', 124), ('lengthwise', 123), ('up', 121), ('plate', 119), ('chives', 117), ('sear', 117), ('browned', 117), ('slices', 117), ('whisk', 114), ('serving', 113), ('single', 112), ('trim', 110), ('mustard', 109), ('using', 108), ('down', 108), ('salmon', 108), ('cooked', 105), ('skin', 105), ('produce', 104), ('cover', 104), ('steaks', 104), ('roughly', 101), ('small', 101), ('beans', 101), ('return', 101), ('spoon', 101), ('coat', 98), ('mince', 96), ('taste', 96), ('or', 95), ('step', 93), ('minute', 91), ('wine', 91), ('dig', 91), ('pieces', 88), ('if', 88), ('parsley', 87), ('bake', 86), ('boil', 85), ('clean', 83), ('pork', 81), ('your', 81), ('juice', 81), ('brown', 81), ('reduced', 81), ('foil', 80), ('crosswise', 80), ('per', 79), ('bring', 78), ('roasted', 78), ('evenly', 78), ('cheese', 77), ('sauté', 77), ('bottom', 74), ('vinegar', 74), ('steak', 72), ('kosher', 72), ('needed', 70), ('separate', 70), ('tomatoes', 69), ('by', 68), ('white', 67), ('burgers', 67), ('ends', 66), ('spinach', 63), ('squash', 63), ('any', 63), ('salad', 63), ('off', 62), ('use', 62), ('sprinkle', 62), ('softened', 62), ('soft', 61), ('rest', 61), ('wipe', 60), ('drain', 59), ('reduce', 59), ('once', 58), ('mushrooms', 58), ('simmer', 57), ('carrots', 56), ('meanwhile', 56), ('asparagus', 55), ('bread', 55), ('liquid', 55), ('at', 54), ('spread', 54), ('garnish', 53), ('whole', 52), ('dressing', 52), ('knife', 49), ('opaque', 49), ('gratin', 49), ('juices', 48), ('fennel', 47), ('slightly', 47), ('mix', 47), ('cup', 47), ('no', 46), ('alongside', 46), ('flip', 45), ('warm', 45), ('sides', 44), ('drizzle', 44), ('chops', 44), ('tarragon', 44), ('leaving', 44), ('light', 44), ('leeks', 44), ('continue', 44), ('crisp', 44), ('foamy', 43), ('each', 43), ('honey', 43), ('packet', 42), ('tin', 42), ('longer', 42), ('enjoy', 42), ('cream', 41), ('finely', 41), ('peas', 41), ('breadcrumbs', 41), ('flour', 41), ('degrees', 41), ('f', 40), ('quarter', 39), ('soften', 39), ('greens', 39), ('toast', 39), ('bits', 39), ('rare', 39), ('pink', 38), ('fully', 38), ('fragrant', 38), ('reserving', 37), ('gruyère', 37), ('ready', 37), ('red', 37), ('parmesan', 37), ('scraping', 37), ('tops', 36), ('keep', 36), ('cold', 35), ('still', 35), ('black', 35), ('nonstick', 35), ('edges', 34), ('arugula', 34), ('potato', 34), ('tomato', 33), ('vinaigrette', 33), ('fork', 33), ('pollock', 33), ('warmed', 33), ('increase', 33), ('sprigs', 32), ('outside', 32), ('grain', 32), ('glass', 31), ('fish', 31)]
# Italian
# [('about', 1228), ('cook', 1185), ('from', 1154), ('then', 1152), ('high', 1134), ('garlic', 1041), ('desired', 975), ('stir', 961), ('chicken', 946), ('water', 937), ('into', 923), ('on', 922), ('tablespoon', 917), ('bowl', 911), ('season', 867), ('large', 836), ('rinse', 811), ('pot', 808), ('recipe', 800), ('tip', 792), ('remove', 783), ('set', 771), ('see', 770), ('remaining', 754), ('when', 754), ('aside', 738), ('cut', 732), ('sauce', 728), ('half', 677), ('halve', 670), ('oven', 662), ('while', 655), ('tomatoes', 632), ('for', 612), ('sheet', 595), ('baking', 578), ('transfer', 575), ('discarding', 574), ('inch', 574), ('paper', 560), ('stirring', 553), ('combine', 551), ('shimmering', 542), ('stems', 538), ('the', 536), ('lemon', 526), ('leaves', 515), ('dry', 501), ('toss', 492), ('place', 477), ('more', 477), ('towel', 476), ('onion', 470), ('slice', 463), ('all', 460), ('between', 457), ('bring', 453), ('boil', 453), ('parmesan', 452), ('side', 445), ('pat', 434), ('chop', 433), ('through', 421), ('butter', 421), ('divide', 421), ('using', 417), ('basil', 402), ('or', 395), ('golden', 389), ('mince', 388), ('thinly', 388), ('pasta', 383), ('tender', 373), ('taste', 370), ('tablespoons', 362), ('preheat', 355), ('roast', 351), ('discard', 343), ('top', 337), ('serve', 336), ('coat', 335), ('small', 332), ('layer', 332), ('parsley', 331), ('plates', 331), ('peel', 329), ('black', 328), ('drain', 316), ('roughly', 304), ('cooked', 302), ('together', 300), ('return', 298), ('your', 297), ('browned', 296), ('are', 296), ('plate', 290), ('whisk', 288), ('up', 287), ('serving', 286), ('vegetables', 285), ('pieces', 283), ('simmer', 280), ('sprinkle', 276), ('needed', 275), ('arrange', 272), ('dig', 272), ('step', 269), ('cooking', 261), ('sauté', 257), ('tomato', 256), ('at', 253), ('potatoes', 251), ('wine', 248), ('spoon', 247), ('garnish', 246), ('reduce', 245), ('shallot', 245), ('down', 240), ('lengthwise', 238), ('minute', 234), ('bake', 232), ('produce', 231), ('clean', 231), ('squash', 230), ('single', 227), ('red', 222), ('roasted', 218), ('slices', 217), ('boiling', 217), ('evenly', 211), ('use', 210), ('off', 208), ('brown', 204), ('juice', 203), ('spinach', 201), ('cup', 198), ('cheese', 196), ('fragrant', 194), ('mozzarella', 193), ('beans', 193), ('white', 190), ('foil', 189), ('once', 189), ('green', 186), ('if', 185), ('crushed', 183), ('still', 179), ('cover', 178), ('paste', 176), ('reserve', 175), ('increase', 173), ('wipe', 169), ('sear', 169), ('cooks', 169), ('crosswise', 168), ('meanwhile', 167), ('vinegar', 166), ('dough', 164), ('liquid', 161), ('beef', 160), ('mix', 156), ('per', 154), ('mushrooms', 153), ('drizzle', 153), ('occasionally', 153), ('breadcrumbs', 151), ('pizza', 151), ('kale', 151), ('finely', 150), ('salad', 150), ('generously', 150), ('flour', 148), ('time', 146), ('separate', 145), ('al', 144), ('it', 143), ('dente', 142), ('warm', 141), ('reserved', 141), ('grill', 140), ('mixture', 140), ('bowls', 140), ('softened', 138), ('reduced', 138), ('skin', 135), ('soft', 135), ('arugula', 134), ('bottom', 132), ('whole', 131), ('tear', 130), ('sided', 128), ('ricotta', 128), ('trim', 126), ('thyme', 126), ('eggplant', 126), ('meatballs', 126), ('pecorino', 124), ('fully', 123), ('sausage', 123), ('pink', 121), ('foamy', 121), ('slightly', 121), ('enjoy', 121), ('oregano', 120), ('by', 120), ('zucchini', 120), ('dressing', 120), ('spaghetti', 120), ('no', 118), ('egg', 118), ('hands', 117), ('knife', 116), ('warmed', 116), ('mustard', 115), ('carefully', 113), ('longer', 112), ('gnocchi', 112), ('dice', 110), ('soften', 109), ('crisp', 109), ('heavy', 109), ('bell', 109), ('ciabatta', 109), ('kosher', 108), ('rosemary', 107), ('toast', 107), ('thick', 107), ('pressing', 104), ('gently', 103), ('peas', 103), ('excess', 103), ('sides', 102), ('orzo', 102), ('crust', 102), ('remainder', 101), ('pesto', 101), ('each', 99), ('chives', 99), ('toasted', 99), ('combined', 99)]
# Mediterranean
# [('teaspoon', 418), ('into', 368), ('about', 365), ('from', 341), ('halve', 329), ('then', 324), ('lemon', 323), ('rinse', 322), ('cut', 315), ('high', 307), ('tablespoon', 301), ('set', 297), ('on', 286), ('stir', 286), ('aside', 283), ('desired', 283), ('remaining', 280), ('cook', 276), ('combine', 275), ('large', 275), ('garlic', 275), ('chicken', 267), ('for', 251), ('while', 248), ('season', 242), ('chop', 238), ('discarding', 235), ('remove', 233), ('inch', 231), ('oven', 227), ('pot', 225), ('recipe', 223), ('tip', 219), ('onion', 219), ('see', 213), ('when', 211), ('water', 206), ('half', 201), ('leaves', 197), ('paper', 194), ('baking', 193), ('stems', 192), ('towel', 189), ('toss', 186), ('tomatoes', 184), ('sheet', 183), ('dry', 183), ('shimmering', 183), ('roughly', 182), ('side', 181), ('transfer', 179), ('pat', 177), ('all', 173), ('serve', 167), ('parsley', 162), ('place', 160), ('top', 150), ('plates', 149), ('roast', 148), ('tablespoons', 148), ('divide', 146), ('tender', 144), ('oregano', 142), ('slice', 141), ('through', 141), ('feta', 141), ('between', 140), ('together', 138), ('juice', 137), ('taste', 137), ('sauce', 136), ('more', 135), ('the', 135), ('coat', 135), ('small', 132), ('black', 129), ('needed', 127), ('cucumber', 126), ('thinly', 125), ('lengthwise', 122), ('preheat', 121), ('or', 119), ('produce', 117), ('mince', 116), ('serving', 114), ('whisk', 113), ('using', 113), ('peel', 112), ('chickpeas', 112), ('bring', 109), ('yogurt', 109), ('boil', 108), ('spinach', 107), ('layer', 107), ('spoon', 107), ('vegetables', 103), ('bell', 101), ('red', 101), ('squash', 98), ('discard', 98), ('potatoes', 98), ('golden', 97), ('browned', 97), ('stirring', 95), ('couscous', 95), ('cooked', 94), ('arrange', 93), ('rice', 93), ('salad', 93), ('step', 92), ('beef', 89), ('wine', 88), ('evenly', 87), ('dig', 87), ('per', 85), ('slices', 83), ('single', 83), ('crosswise', 83), ('mix', 82), ('return', 82), ('pieces', 80), ('dill', 78), ('plate', 78), ('your', 77), ('if', 77), ('vinegar', 76), ('cover', 75), ('drain', 75), ('steak', 73), ('up', 72), ('down', 72), ('sear', 71), ('are', 71), ('roasted', 70), ('tomato', 69), ('seeds', 68), ('off', 68), ('quinoa', 67), ('simmer', 66), ('at', 66), ('salmon', 66), ('slightly', 65), ('marinade', 65), ('reduce', 64), ('foil', 64), ('finely', 63), ('eggplant', 63), ('skin', 61), ('warm', 61), ('naan', 61), ('dressing', 61), ('once', 60), ('garnish', 60), ('use', 59), ('steaks', 59), ('cooks', 59), ('peppers', 58), ('minute', 58), ('ready', 57), ('olives', 57), ('sauté', 57), ('zucchini', 56), ('lamb', 56), ('clean', 53), ('toasted', 52), ('za', 52), ('atar', 52), ('mint', 51), ('dice', 51), ('separate', 51), ('white', 51), ('drizzle', 51), ('meanwhile', 51), ('marinate', 50), ('brown', 50), ('out', 49), ('cup', 48), ('sprinkle', 48), ('spice', 48), ('greek', 48), ('remainder', 47), ('still', 46), ('bake', 46), ('temperature', 45), ('shallot', 45), ('kosher', 45), ('wedges', 44), ('whole', 44), ('room', 44), ('degrees', 44), ('softened', 44), ('fully', 42), ('pinch', 42), ('mixture', 42), ('any', 42), ('f', 42), ('bottom', 41), ('boiling', 41), ('fragrant', 40), ('pour', 40), ('fork', 39), ('herbs', 39), ('scallion', 39), ('just', 39), ('rest', 39), ('wipe', 38), ('trim', 38), ('excess', 38), ('squeeze', 38), ('warmed', 38), ('pink', 37), ('scoop', 37), ('egg', 37), ('flip', 37), ('sides', 37), ('plastic', 37), ('liquid', 37), ('kale', 36), ('butter', 36), ('enjoy', 36), ('you', 35), ('no', 34), ('keeping', 34), ('greens', 34), ('paste', 34), ('reserving', 34), ('grill', 34), ('longer', 33), ('arugula', 33), ('zest', 33), ('low', 32), ('wrap', 32), ('next', 32), ('combined', 32), ('bag', 32), ('toast', 32), ('increase', 32), ('cups', 31), ('line', 31), ('crisp', 31)]
# American
# [('olive', 1455), ('bowl', 1345), ('from', 1323), ('on', 1274), ('then', 1234), ('into', 1224), ('desired', 1119), ('cook', 1119), ('high', 1074), ('cut', 1046), ('tablespoon', 1045), ('rinse', 1036), ('set', 1031), ('season', 1011), ('aside', 992), ('chicken', 990), ('remaining', 953), ('when', 942), ('halve', 935), ('remove', 915), ('tip', 900), ('recipe', 877), ('large', 865), ('while', 848), ('for', 846), ('see', 842), ('oven', 825), ('garlic', 823), ('inch', 793), ('transfer', 783), ('slice', 759), ('stir', 758), ('side', 757), ('pot', 745), ('combine', 745), ('the', 728), ('paper', 727), ('sheet', 726), ('lemon', 721), ('potatoes', 718), ('half', 710), ('baking', 702), ('toss', 691), ('towel', 682), ('shimmering', 679), ('water', 674), ('place', 666), ('dry', 656), ('butter', 614), ('discarding', 612), ('pat', 606), ('thinly', 605), ('all', 594), ('roast', 559), ('leaves', 551), ('more', 549), ('onion', 542), ('tender', 537), ('using', 537), ('stems', 536), ('sauce', 530), ('top', 529), ('through', 513), ('stirring', 512), ('serve', 511), ('discard', 499), ('chop', 491), ('plates', 488), ('together', 480), ('small', 478), ('golden', 473), ('between', 467), ('divide', 464), ('preheat', 452), ('layer', 450), ('whisk', 450), ('plate', 421), ('vegetables', 419), ('browned', 418), ('are', 408), ('peel', 405), ('juice', 398), ('taste', 397), ('cover', 383), ('or', 379), ('tablespoons', 379), ('mince', 377), ('serving', 370), ('arrange', 367), ('boil', 367), ('sear', 366), ('coat', 363), ('lengthwise', 361), ('your', 349), ('black', 349), ('shallot', 345), ('single', 344), ('bring', 340), ('down', 340), ('needed', 337), ('slices', 335), ('cooked', 333), ('roughly', 328), ('step', 328), ('roasted', 321), ('steaks', 318), ('tomatoes', 314), ('cheese', 311), ('brown', 309), ('up', 307), ('produce', 305), ('dig', 301), ('clean', 296), ('return', 295), ('spoon', 295), ('skin', 294), ('squash', 289), ('reduce', 289), ('mix', 288), ('per', 283), ('parsley', 282), ('pieces', 279), ('pork', 274), ('vinegar', 273), ('kale', 272), ('beans', 269), ('burgers', 268), ('off', 266), ('mustard', 264), ('drain', 257), ('evenly', 257), ('steak', 256), ('simmer', 255), ('wipe', 254), ('crosswise', 252), ('chives', 246), ('salad', 243), ('quinoa', 241), ('green', 239), ('sprinkle', 239), ('use', 239), ('trim', 236), ('sauté', 230), ('at', 226), ('separate', 224), ('if', 220), ('garnish', 218), ('thyme', 216), ('foil', 213), ('spinach', 212), ('cup', 210), ('fully', 205), ('dressing', 204), ('bake', 202), ('kosher', 197), ('once', 195), ('bottom', 192), ('meanwhile', 190), ('minute', 190), ('apple', 186), ('sweet', 185), ('flip', 185), ('mushrooms', 183), ('mayonnaise', 179), ('whole', 178), ('rest', 177), ('spice', 177), ('warm', 176), ('corn', 176), ('cooks', 176), ('no', 174), ('softened', 174), ('rice', 173), ('carrots', 172), ('crisp', 172), ('sides', 172), ('still', 171), ('drizzle', 170), ('dice', 169), ('salmon', 168), ('each', 166), ('potato', 165), ('longer', 164), ('finely', 163), ('tomato', 163), ('pink', 162), ('buns', 162), ('mixture', 162), ('enjoy', 162), ('light', 159), ('ready', 157), ('greens', 156), ('red', 153), ('slightly', 151), ('it', 151), ('white', 151), ('arugula', 150), ('carefully', 149), ('wine', 148), ('hands', 146), ('flour', 145), ('bread', 145), ('degrees', 145), ('soften', 143), ('combined', 143), ('toast', 140), ('f', 140), ('paste', 139), ('occasionally', 138), ('grill', 137), ('smooth', 137), ('knife', 135), ('seeds', 134), ('any', 133), ('keep', 131), ('rare', 131), ('remainder', 130), ('fork', 130), ('soft', 130), ('spread', 129), ('egg', 128), ('liquid', 128), ('increase', 127), ('sprouts', 126), ('basil', 126), ('foamy', 126), ('parmesan', 125), ('brussels', 123), ('bell', 122), ('honey', 122), ('alongside', 121), ('low', 120), ('sugar', 117), ('lime', 117), ('cider', 116), ('both', 115), ('save', 114), ('grain', 114), ('beginning', 112), ('tops', 112)]
# Middle-eastern
# [('olive', 266), ('chicken', 252), ('into', 234), ('halve', 211), ('set', 209), ('then', 208), ('on', 204), ('lemon', 201), ('water', 201), ('remaining', 201), ('desired', 197), ('aside', 192), ('garlic', 189), ('from', 189), ('rinse', 186), ('about', 181), ('high', 180), ('tablespoon', 178), ('combine', 169), ('onion', 163), ('large', 163), ('pot', 161), ('cut', 155), ('recipe', 152), ('tip', 152), ('oven', 146), ('inch', 146), ('parsley', 145), ('half', 145), ('while', 145), ('see', 144), ('season', 143), ('stir', 140), ('discarding', 139), ('for', 138), ('juice', 133), ('tablespoons', 128), ('toss', 124), ('cook', 123), ('leaves', 122), ('small', 121), ('chop', 120), ('remove', 119), ('when', 118), ('sheet', 116), ('baking', 115), ('stems', 114), ('together', 111), ('chickpeas', 109), ('whisk', 108), ('all', 107), ('side', 107), ('paper', 104), ('the', 104), ('transfer', 102), ('roast', 97), ('shimmering', 97), ('dry', 96), ('place', 95), ('mix', 94), ('sauce', 94), ('roughly', 93), ('lengthwise', 91), ('towel', 91), ('tomatoes', 91), ('tahini', 91), ('pat', 90), ('slice', 88), ('or', 88), ('serve', 88), ('mince', 87), ('using', 87), ('top', 87), ('preheat', 85), ('tender', 85), ('between', 82), ('thinly', 80), ('peel', 77), ('divide', 77), ('at', 76), ('layer', 75), ('bring', 74), ('boil', 74), ('through', 74), ('serving', 73), ('black', 72), ('spice', 72), ('produce', 69), ('coat', 69), ('are', 69), ('cover', 68), ('couscous', 67), ('rice', 67), ('arrange', 66), ('plate', 66), ('plates', 66), ('more', 65), ('needed', 64), ('eggplant', 64), ('taste', 64), ('cucumber', 63), ('pieces', 62), ('single', 61), ('drizzle', 61), ('vegetables', 61), ('carrots', 60), ('browned', 60), ('your', 59), ('crosswise', 58), ('drain', 58), ('skin', 57), ('warm', 57), ('up', 56), ('step', 55), ('harissa', 55), ('stirring', 55), ('yogurt', 54), ('cooked', 54), ('mint', 53), ('simmer', 52), ('salad', 50), ('golden', 49), ('naan', 49), ('paste', 49), ('dig', 49), ('bell', 48), ('return', 48), ('dressing', 48), ('garnish', 48), ('cup', 47), ('down', 46), ('use', 46), ('per', 45), ('reduce', 44), ('quinoa', 44), ('discard', 43), ('ready', 42), ('smooth', 42), ('evenly', 41), ('roasted', 41), ('sprinkle', 41), ('off', 41), ('feta', 39), ('cooks', 39), ('if', 38), ('spinach', 38), ('fully', 38), ('tomato', 38), ('separate', 36), ('still', 36), ('spoon', 36), ('sear', 36), ('beef', 36), ('foil', 35), ('seeds', 35), ('herbs', 35), ('pita', 35), ('longer', 35), ('pink', 35), ('mixture', 35), ('cilantro', 34), ('no', 34), ('it', 33), ('once', 33), ('room', 32), ('za', 32), ('atar', 32), ('crisp', 32), ('bulgur', 32), ('cauliflower', 31), ('finely', 31), ('egg', 31), ('slices', 31), ('squash', 31), ('bake', 31), ('marinate', 30), ('temperature', 30), ('potatoes', 30), ('meanwhile', 30), ('honey', 29), ('butter', 29), ('shakshuka', 29), ('red', 28), ('toast', 28), ('boiling', 28), ('slightly', 28), ('dice', 27), ('lamb', 27), ('kosher', 27), ('time', 27), ('hands', 26), ('fork', 26), ('carefully', 26), ('grill', 26), ('enjoy', 26), ('orange', 25), ('plastic', 25), ('pinch', 25), ('low', 25), ('brown', 25), ('gently', 25), ('you', 24), ('peppers', 24), ('clean', 24), ('liquid', 24), ('charred', 24), ('bag', 23), ('vinegar', 23), ('pour', 23), ('degrees', 23), ('f', 23), ('whisking', 23), ('moons', 22), ('thick', 22), ('remainder', 22), ('flip', 22), ('kale', 22), ('just', 22), ('cups', 22), ('knife', 22), ('reserving', 22), ('fragrant', 22), ('wrap', 22), ('bowls', 22), ('s', 22), ('soft', 22), ('meatballs', 22), ('have', 21), ('form', 21), ('shallot', 21), ('dough', 21), ('minute', 21), ('combined', 21), ('softened', 21), ('any', 21), ('stem', 20), ('marinade', 20), ('turn', 20), ('wine', 20), ('tear', 20)]
